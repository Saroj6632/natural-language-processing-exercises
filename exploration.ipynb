# %%
import re
import unicodedata
import pandas as pd
import nltk
from pydataset import data
import env

# %% [markdown]
# # Do your work for this exercise in a file named explore.
#
# # 1. Spam Data
# - a. Load the spam data set.
# - b. Create and explore bigrams for the spam data. Visualize them with a word cloud. How do they compare with the ham bigrams?
# - c. Is there any overlap in the bigrams for the spam data and the ham data?
# - d. Create and explore with trigrams (i.e. a n-gram with an n of 3) for both the spam and ham data.

# %%
''' function to connect to CodeUp SQL database'''
def get_connection(db, user=env.username, host=env.host, password=env.password):
    return f'mysql+pymysql://{env.username}:{env.password}@{env.host}/{db}'

# %%
url= get_connection('spam_db')
sql= 'select * from spam'

# %%
df= pd.read_sql(sql,url, index_col='id')
df.head()

# %%
df.label.value_counts()

# %%
# create a data frame with the percentage of ham and spam
labels= pd.concat([df.label.value_counts(),df.label.value_counts(normalize=True)],axis=1)
labels.columns=['n','percent']
labels

# %%
 #lets do some data preparation
    
import unicodedata
import re
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
import pandas as pd

# %%
# creating a cleaning function that will lower the text, encode using ascii and decode it back
# this function also replaces anything thats not a-z, 0-9, and white space with nothing
def basic_clean(text):
    text = unicodedata.normalize('NFKD', text.lower())\
        .encode('ascii', 'ignore')\
        .decode('utf-8', 'ignore')
    return re.sub(r"[^a-z0-9\s]", '', text)

# %%
# create a new column that is the cleaned version of the selected column and name that column text_cleaned
df['text_cleaned'] = df.text.apply(basic_clean)
df.head()

# %%
# lets create a tokenize function

def tokenize(string):
    '''
    This function takes in a string and
    returns a tokenized string.
    '''
    # Create tokenizer.
    tokenizer = nltk.tokenize.ToktokTokenizer()
    
    # Use tokenizer
    string = tokenizer.tokenize(string, return_str=True)
    
    return string

# %%
# add a tokenized column to the dataframe by applying tokenize function 
df['text_tokenized']= df.text_cleaned.apply(tokenize)
df.head(2)

# %%
# lets create a lemmatize function

def lemmatize(string):
    '''
    This function takes in string for and
    returns a string with words lemmatized.
    '''
    # Create the lemmatizer.
    wnl = nltk.stem.WordNetLemmatizer()
    
    # Use the lemmatizer on each word in the list of words we created by using split.
    lemmas = [wnl.lemmatize(word) for word in string.split()]
    
    # Join our list of words into a string again and assign to a variable.
    string = ' '.join(lemmas)
    
    return string

# %%
# lets create a new column that is the lemmatized version of the tokenized text and name that column text_lemmatized

df['text_lemmatized'] = df.text_tokenized.apply(lemmatize)
df.head()

# %%
def remove_stopwords(string, extra_words=[], exclude_words=[]):
    '''
    This function takes in a string, optional extra_words and exclude_words parameters
    with default empty lists and returns a string.
    '''
    # Create stopword_list.
    stopword_list = stopwords.words('english')
    
    # Remove 'exclude_words' from stopword_list to keep these in my text.
    stopword_list = set(stopword_list) - set(exclude_words)
    # Add in 'extra_words' to stopword_list.
    stopword_list = stopword_list.union(set(extra_words))
    
    # Split words in string.
    words = string.split()
    
    # Create a list of words from my string with stopwords removed and assign to variable.
    filtered_words = [word for word in words if word not in stopword_list]
    
    # Join words in the list back into strings and assign to a variable.
    string_without_stopwords = ' '.join(filtered_words)
    
    return string_without_stopwords

# %%
# lets filter the text by removing the stop words and give it a name text_filtered

df['text_filtered'] = df.text_lemmatized.apply(remove_stopwords)
df.head()

# %%
# lets split the filtered text and then substitute anything thats not a-z, 0-9, white space or single item
# with nothing 
words = [re.sub(r'([^a-z0-9\s]|\s.\s)', '', doc).split() for doc in df.text_filtered]

# lets concat into the main dataframe
# column name will be words, and the column will contain lists of the words in each doc
df = pd.concat([df, pd.DataFrame({'words': words})], axis=1)

# %%
df

# %%
# to get all of the hamwords, we are filtering the data by label == ham and then joining all of the filtered text

ham_words = ' '.join(df[df.label=='ham'].text_filtered)

# to get all the spamwords, we are filtering the data by label == spam and joining all of the filtered text
spam_words = ' '.join(df[df.label=='spam'].text_filtered)

# doing the same thing but without filtering the dataframe and calling it all words
all_words = ' '.join(df.text_filtered)

# substituting space anything space with nothing in all three of the words
ham_words = re.sub(r'\s.\s', '', ham_words)
spam_words = re.sub(r'\s.\s', '', spam_words)
all_words = re.sub(r'\s.\s', '', all_words)

spam_words

# %%
# lets get the frequency of the words within each word group

ham_freq = pd.Series(ham_words.split()).value_counts()

spam_freq = pd.Series(spam_words.split()).value_counts()

all_freq = pd.Series(all_words.split()).value_counts()

# check the top 5 word counts in all words
all_freq.head()

# %%
# lets create a dataframe that holds the word count from all words, ham words, and spam words

word_counts = (pd.concat([all_freq, ham_freq, spam_freq], axis=1, sort=True)
               .set_axis(['all', 'ham', 'spam'], axis=1, inplace=False)
               .fillna(0)
               .apply(lambda s: s.astype(int))
              )


# lets take a look at the dataframe
word_counts.head()


# lets sort

word_counts.sort_values(by='all', ascending=False).head(10)

# %% [markdown]
# **Takeaways:**
#
# - We can see a certain words being used more frequently in one category vs the other.  im is barely used in spam
#
# - **dont** is barely used in spam
#
# - **free** is mostly used in spam
#
# - **call** is more frequent in spam

# %%
# lets check the words that are only used in ham
word_counts[word_counts.spam==0].sort_values(by='ham').tail(10)

# %%
# lets check the words that are only used in spam
word_counts[word_counts.ham==0].sort_values(by='spam').tail(10)

# %%
df.head()

# %%
# lets create a column that holds the count of words in column words
df['doc_length'] = [len(wordlist) for wordlist in df['words']]

# %%
df.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
word_counts.assign(p_spam = word_counts.spam/word_counts['all'],
                  p_ham = word_counts.ham/word_counts['all']).sort_values(by = 'all')[['p_spam', 'p_ham']]\
.tail(20).sort_values('p_ham').plot.barh(stacked = True)
    
plt.title('Proportion of Spam vs Ham for the 20 most commot words in our text sample')

# %%
word_counts.assign(p_spam = word_counts.spam/word_counts['all'],
                  p_ham = word_counts.ham/word_counts['all']).sort_values('all')[['p_spam', 'p_ham']].tail(20).sort_values('p_ham')

# %%
from wordcloud import WordCloud

# %%
ham_cloud = WordCloud(background_color = 'white', height = 1000, width = 1000).generate(ham_words)

plt.imshow(ham_cloud)

# %%
spam_cloud = WordCloud(background_color = 'white', height = 1000, width = 1000).generate(spam_words)
plt.imshow(spam_cloud)

# %%
axs = plt.axes([0.25,1,.5,.5]), plt.axes([0.8,1,.5,.5])

axs[0].imshow(ham_cloud)
axs[1].imshow(spam_cloud)

# %%
# creating a bigram column that holds the bigram of the words in each observation

df['bigrams'] = [list(nltk.ngrams(wordlist, 2)) for wordlist in df.words]
df.head()

# %%
# lets create a bigrams of all of the text in ham and all of the text in spam

ham_bigrams = pd.Series(list(nltk.ngrams(ham_words.split(), 2))).value_counts().head(20)
spam_bigrams = pd.Series(list(nltk.ngrams(spam_words.split(), 2))).value_counts().head(20)
spam_bigrams

# %%
# lets plot these bigrams 

plt.subplot(121)
ham_bigrams.plot.barh(color = 'purple', width = 0.9, figsize = (10,10), alpha = 0.8)
plt.title('20 most frequently occuring ham bigrams')
plt.ylabel('Bigram')
plt.xlabel('Frequency')

plt.subplot(122)
spam_bigrams.plot.barh(color = 'purple', width = 0.9, figsize = (10,10), alpha = 0.8)
plt.title('20 most frequently occuring spam bigrams')
plt.ylabel('Bigram')
plt.xlabel('Frequency')
plt.tight_layout()

# %%
# lets explore tri-grams
ham_trigrams = pd.Series(list(nltk.ngrams(ham_words.split(), 3))).value_counts().head(20)
spam_trigrams = pd.Series(list(nltk.ngrams(spam_words.split(), 3))).value_counts().head(20)
spam_trigrams

# %%
# lets plot these trigrams 

plt.subplot(121)
ham_trigrams.plot.barh(color = 'purple', width = 0.9, figsize = (10,10), alpha = 0.8)
plt.title('20 most frequently occuring ham trigrams')
plt.ylabel('trigram')
plt.xlabel('Frequency')

plt.subplot(122)
spam_trigrams.plot.barh(color = 'purple', width = 0.9, figsize = (10,10), alpha = 0.8)
plt.title('20 most frequently occuring spam trigrams')
plt.ylabel('trigram')
plt.xlabel('Frequency')
plt.tight_layout()

# %% [markdown]
# # 2. Explore the blog articles using the techniques discussed in the exploration lesson.

# %%
import acquire
import prepare
import re
import json
import pandas as pd

# %%
blogs_df= acquire.get_blog_articles()
blogs_df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 blogs_df= acquire.get_blog_articles()
#       2 blogs_df.head()
#
# File ~/codeup-data-science/natural-language-processing-exercises/acquire.py:92, in get_blog_articles()
#      90 title = soup.title.string
#      91 article = soup.find('div', class_ = 'jupiterx-post-content')
# ---> 92 article_text = article.text
#      93 item = {
#      94     'title': title,
#      95     'content': article_text
#      96 }
#      97 lst.append(item)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# # 3. Explore the news articles using the techniques discussed in the exploration lesson. Use the category variable when exploring.

# %%
news_df= acquire.get_news_articles()
news_df
# Out:
# [{'title': "Don't eff this up: Bezos recalls warning from son for Lord of Rings' prequel",
#   'content': 'Ahead of the debut of The Lord of the Rings\' prequel \'Rings of Power\' on Amazon\'s Prime Video, Jeff Bezos revealed a conversation he had with his son. He said, "My son came up to me one day, he looked me in the eyes, very sincerely, and he said: \'Dad, please don\'t eff this up\'...And he was right."',
#   'category': 'business'},
#  {'title': "Snap CEO confirms 20% job cuts, says 'We must reduce cost to avoid ongoing losses'",
#   'content': 'In a letter to staff posted on Snap’s website, CEO Evan Spiegel has confirmed 20% job cuts at the company as the latest quarterly revenue growth of 8% was "well below" expectations. Spiegel wrote, "Unfortunately, given our current lower rate of revenue growth, it has become clear that we must reduce our cost structure to avoid incurring significant ongoing losses."',
#   'category': 'business'},
#  {'title': 'Price of commercial LPG cylinders cut by up to ₹100; list of rates in cities released',
#   'content': 'State-owned fuel retailers on Thursday announced a reduction in the prices of commercial LPG cylinders. From today, a 19-kg commercial LPG cylinder will be cheaper by ₹91.50 in Delhi and will be available for ₹1,885 instead of the earlier ₹1,976.50. Apart from Delhi, the prices have been reduced by up to ₹100 in Kolkata, Chennai and Mumbai.',
#   'category': 'business'},
#  {'title': "Chairman of Russia's 2nd largest oil firm dies after fall from hospital window: Reports",
#   'content': "The chairman of Russia's second-largest oil producer Lukoil died on Thursday after falling from a hospital window, as per reports. Ravil Maganov, 67, was being treated at the city's Central Clinical Hospital and died from his injuries, reported Russian media. Maganov is the second top executive at Lukoil to die under mysterious circumstances in recent months.",
#   'category': 'business'},
#  {'title': 'SpiceJet shares fall nearly 15% after CFO resigns amid widening losses',
#   'content': 'SpiceJet shares declined nearly 15% during Thursday’s intraday trade to a one-month low after the airline reported widening of net loss to ₹789 crore in the June quarter. Notably, its CFO Sanjeev Taneja also resigned amid losses and a series of mid-air incidents. SpiceJet stock, which has fallen over 36% so far this year, was currently trading at ₹44.15.',
#   'category': 'business'},
#  {'title': 'August GST revenue collection jumps 28% YoY at ₹1.44 lakh crore',
#   'content': 'The Goods and Services Tax (GST) revenue increased by 28% to ₹1,43,612 crore in August as against ₹1,12,020 crore in the corresponding month last year, the Finance Ministry said. GST revenue crossed the ₹1.40 lakh crore mark for the sixth consecutive month led by robust economic recovery and compliance, the ministry added. The growth till August 2022 is 33% y-o-y.\n',
#   'category': 'business'},
#  {'title': 'Value of UPI transactions touches all-time high of ₹10.73 lakh cr in Aug',
#   'content': "Value of digital payment transactions through UPI touched an all-time high of ₹10.73 lakh crore with 657 crore transactions in August 2022, according to National Payments Corporation of India's (NPCI) latest data. UPI transaction value in July was at ₹10.63 lakh crore with 628 crore transactions. UPI transaction value crossed the ₹10-lakh-crore mark for the first time in May.",
#   'category': 'business'},
#  {'title': "SpiceJet makes payments in 'graded format', delays salaries for 2nd straight month",
#   'content': 'SpiceJet employees have alleged a delay in their salaries for the second consecutive month. Meanwhile, the airline said that the salaries will be credited in a "graded format". In an internal communication, mentioning the delay, SpiceJet said the "previous few months have been difficult" due to a "superlative fuel price hike" and also a "historically lean period of July-September".',
#   'category': 'business'},
#  {'title': "Taiwan looks forward to producing 'democracy chips' with US: Prez",
#   'content': 'Taiwan President Tsai Ing-wen told the governor of the US state of Arizona, Doug Ducey, that the island nation is looking forward to producing "democracy chips" with the US. Taiwan Semiconductor Manufacturing Co Ltd (TSMC) is constructing a $12 billion plant in Arizona. Ducey told Tsai that partnership with Taiwan was "the greatest" in the semiconductor industry.',
#   'category': 'business'},
#  {'title': 'Dennis Woodside appointed as President of Freshworks',
#   'content': "Nasdaq-listed software-as-a-service (SaaS) company Freshworks has appointed Dennis Woodside as the company's President, effective from September 1. Woodside will join the company's board of directors and will report to Freshworks CEO and Founder Girish Mathrubootham. Previously, he was President of Impossible Foods, and also worked at Dropbox and Google. At Freshworks, he will lead global business operations.",
#   'category': 'business'},
#  {'title': 'EU mulls over capping energy prices, cutting electricity demand',
#   'content': "The European Commission is looking into measures to cap energy prices and cut electricity demand, Mechthild Wörsdörfer, Deputy Director General of the European Commission's energy department said. She mentioned that European Commission chief Ursula von der Leyen will outline ideas on capping energy prices on September 14. Russia had cut gas deliveries to Europe which led to rise in prices.",
#   'category': 'business'},
#  {'title': 'IMF provisionally agrees to give crisis-hit Sri Lanka $2.9-bn loan',
#   'content': "The International Monetary Fund (IMF) on Thursday said that it has provisionally agreed to give a loan of about $2.9 billion to Sri Lanka which is grappling with an economic crisis. IMF and Sri Lanka have entered a 48-month-long arrangement under the former's Extended Fund Facility. The agreement is subject to approval by the IMF management and its Executive Board.\n",
#   'category': 'business'},
#  {'title': "Moody's cuts India's growth forecast to 7.7% from 8.8% for 2022",
#   'content': "Global credit rating agency Moody's Investors Service cut India's economic growth projection to 7.7% for 2022 from its May projection of 8.8%. It said that the economic momentum will slow down on a sequential basis owing to rising interest rates, uneven monsoon and slowing global growth. However, the rating agency said the services and manufacturing sectors have seen robust upswings.",
#   'category': 'business'},
#  {'title': "SpiceJet CFO resigns after airline's Q1 net loss widens to ₹789 cr",
#   'content': "SpiceJet's Chief Financial Officer (CFO) Sanjeev Taneja resigned from his post amid the airline reporting a widening of net loss to ₹789 crore during the April-June quarter, on Wednesday. The loss in the corresponding period last fiscal was ₹729 crore. SpiceJet said that its Board has identified a candidate for Taneja's replacement and the vacancy would be filled in September.\n",
#   'category': 'business'},
#  {'title': 'Yen drops to 24-year low to 139.59/dollar as Treasury yields rise',
#   'content': 'The yen fell to its lowest to 139.59 per dollar in Thursday’s trading recording a 24-year low as US Treasury yields surged through 3.2% owing to the Federal Reserve’s hawkish stance at the Jackson Hole symposium. During the 1998 Asian financial crisis, the yen had reached around 146 to the dollar. Japan had previously intervened at levels around 130.',
#   'category': 'business'},
#  {'title': 'Centre hikes windfall profit tax on export of diesel, ATF',
#   'content': 'The government has increased the windfall profit tax on the export of diesel to ₹13.5 per litre from ₹7, while that on aviation turbine fuel exports to ₹9 per litre from ₹2. The tax on domestically-produced crude oil has also been hiked by ₹300 per tonne to ₹13,300. The prices come into effect from Thursday, a Finance Ministry notification said.',
#   'category': 'business'},
#  {'title': 'Lufthansa to cancel almost all flights on Friday from 2 German cities amid strike',
#   'content': 'German airline Lufthansa has said that it will cancel almost all passenger and cargo flights on Friday from Frankfurt and Munich amid a wage dispute. The pilots\' union Vereinigung Cockpit demanded 5.5% pay raise this year for more than 5,000 pilots. However, the union\'s spokesperson said, "We have not received a sufficient offer...this is sobering and a missed opportunity."',
#   'category': 'business'},
#  {'title': 'Markets end in red with Sensex falling 770 points, Nifty at 17,542',
#   'content': 'The benchmark indices ended in the red on Thursday with Sensex falling 770.48 points to 58,766.59. Nifty ended 216.5 points lower at 17,542.80 dragged by IT, metal, power and oil and gas stocks. Hindalco Industries, Reliance Industries, ONGC and TCS were among the top Nifty losers, while stocks of Tata Consumer Products, Bajaj Finserv, Asian Paints and Eicher Motors gained.\n',
#   'category': 'business'},
#  {'title': 'NPCI in talks to acquire 10% stake in ONDC: Reports',
#   'content': "The National Payments Corporation of India (NPCI) is reportedly in talks to acquire a 10% stake in Open Network for Digital Commerce (ONDC), India's open source platform for e-commerce. Reportedly, the Bank of India is also looking to acquire a 5-7% stake in the company. ONDC currently has 17 stakeholders and is aiming to have 20. ",
#   'category': 'business'},
#  {'title': 'Sensex falls 700 points, Nifty at 17,558 in opening trade',
#   'content': 'Benchmark indices opened in the red on Thursday with Sensex falling 707.39 points at 58,829.68 and Nifty down 200.80 points at 17,558.50. Infosys, SBI Life Insurance, TCS, Hindalco Industries, ONGC were among the major Nifty losers, while the shares of Bharti Airtel, Bajaj Auto, IndusInd Bank, Bajaj Finserv and UltraTech Cement gained. Nearly 1,101 shares advanced and 1,052 shares declined.',
#   'category': 'business'},
#  {'title': 'Unemployment rate fell to 7.6% during Apr-June in urban areas: NSO',
#   'content': 'The unemployment rate for people in the age group of 15 years and above in urban areas dropped to 7.6% during April-June 2022 from 12.6% in the corresponding period last year, the National Statistical Office (NSO) said. This was led by an improved labour force participation ratio, pointing towards a sustained economic recovery after the COVID-19 pandemic.\n',
#   'category': 'business'},
#  {'title': 'Share prices of fuel exporters fall after windfall profit tax hike',
#   'content': 'After the Centre increased the windfall profit tax on the export of diesel and aviation turbine fuel, the shares of Indian fuel exporters dropped up to 3% in the morning trade on Thursday. ONGC declined by 2.2%, Reliance Industries Limited fell by 1.5%, Chennai Petroleum Corporation Limited by 3.3%, Mangalore Refinery & Petrochemicals by 1.5% and Oil India dropped 0.5%.\n',
#   'category': 'business'},
#  {'title': 'April-July fiscal deficit at ₹3.40 lakh crore, 20.5% of FY23 target',
#   'content': "The Centre's fiscal deficit was 20.5% of the annual target in July end as against 21.3% in the year-ago period, the Controller General of Accounts data showed. The fiscal deficit was ₹3.40 lakh crore during the April-July period in actual terms. For the full FY23, the fiscal deficit is pegged at ₹16.6 lakh crore or 6.4% of the GDP.",
#   'category': 'business'},
#  {'title': 'India beat Hong Kong to reach Asia Cup Super 4 as Suryakumar breaks multiple records',
#   'content': 'India beat Hong Kong by 40 runs to qualify for Super 4 stage of Asia Cup 2022. Suryakumar Yadav slammed 68*(26), the highest score by a batter in the ongoing tournament. He also recorded most sixes by an Indian (six) in a T20 Asia Cup match and most runs by an Indian (26) in 20th over of a T20I match.',
#   'category': 'sports'},
#  {'title': 'Suryakumar Yadav smashes most sixes ever by an Indian in a T20 Asia Cup match',
#   'content': "Suryakumar Yadav on Wednesday broke the record for smashing the most number of sixes by a Team India batter in a men's T20 Asia Cup match. Suryakumar slammed six sixes against Hong Kong on Wednesday. No other Indian batter has slammed more than three sixes in a men's T20 Asia Cup match. Suryakumar scored 68*(26) against Hong Kong.",
#   'category': 'sports'},
#  {'title': 'Hong Kong cricketer Kinchit proposes to his girlfriend in stadium after India match',
#   'content': "Hong Kong batter Kinchit Shah proposed to his girlfriend in the stadium after his team's Asia Cup 2022 match against India in Dubai on Wednesday. A video went viral showing Kinchit going down on one knee and offering the ring to his girlfriend, who accepted his proposal. Fans and his teammates were seen cheering for him during the proposal.",
#   'category': 'sports'},
#  {'title': "Simply can't fathom this approach: Venkatesh Prasad on KL Rahul's 36(39) vs Hong Kong",
#   'content': 'Reacting to KL Rahul\'s 39-ball 36-run knock against Hong Kong, former India fast bowler Venkatesh Prasad tweeted, "Is there something in the pitch that is not visible?" He added, "Simply can\'t fathom this approach especially from KL Rahul." India scored 70 runs in their first 10 overs against Hong Kong, but went on to put up a total of 192/2.',
#   'category': 'sports'},
#  {'title': 'Australia announce their squad for T20 World Cup 2022',
#   'content': "Defending champions Australia have announced their squad for T20 World Cup 2022. Batter Tim David has been included in the 15-member squad. His selection over leg-spinner Mitchell Swepson is the only change from the group that won the T20 World Cup 2021 in the UAE. Australia's T20 World Cup 2022 campaign will begin against New Zealand on October 22.",
#   'category': 'sports'},
#  {'title': 'Virat Kohli bowls in T20I cricket after 6 years, concedes 6 runs in an over',
#   'content': 'Former Team India captain Virat Kohli on Wednesday bowled an over against Hong Kong in their Asia Cup 2022 match. It is the first time since 2016 that Kohli bowled in a T20I match. He gave away six runs in his over. Kohli has bowled 25.2 overs in T20I cricket, taking four wickets for 204 runs.',
#   'category': 'sports'},
#  {'title': "Are you saying Rahul should be dropped: Suryakumar to journalist asking if he'd open",
#   'content': 'After a journalist asked Suryakumar Yadav if he\'d open with Rohit Sharma at some point in Asia Cup, Suryakumar Yadav jokingly replied, "Are you saying...KL Rahul should be dropped?" He added, "I\'m really flexible to bat at any number. I\'ve told coach and captain that they can play me at any number but I want to be in the team."',
#   'category': 'sports'},
#  {'title': 'Hong Kong gift jersey with handwritten message to Virat Kohli, he shares pic',
#   'content': 'Hong Kong gifted a jersey with a handwritten message on it to Virat Kohli following their Asia Cup match against India. Kohli took to his Instagram Stories to share a picture of the jersey. "Virat...Thank you for inspiring a generation. We stand with you! There are many incredible days ahead. With strength, with love, Team Hong Kong," the message read.',
#   'category': 'sports'},
#  {'title': "I was wondering why he wasn't leaving the field: Suryakumar on Virat Kohli's gesture",
#   'content': 'On being asked about Virat Kohli bowing down to him and asking him to walk out of the field first after his knock of 68*(26) against Hong Kong, Suryakumar Yadav said, "It was a heartwarming gesture." He added, "I\'ve never seen something like this. I was wondering why he wasn\'t leaving the field. I loved batting with him."',
#   'category': 'sports'},
#  {'title': "How do the Asia Cup 2022 points tables read after India's victory against Hong Kong?",
#   'content': "With their 40-run victory against Hong Kong in Asia Cup 2022, India confirmed a first-place finish in Group A and advanced to Super 4. Pakistan and Hong Kong, who'll face each other on Friday, are placed second and third, respectively. Meanwhile, Afghanistan are on top of Group B points table, with Bangladesh and Sri Lanka being second and third, respectively. ",
#   'category': 'sports'},
#  {'title': "Rahul's 36, Kohli's fifty, Jadeja's bowling, all positives from India vs HK: Irfan",
#   'content': 'Ex-India cricketer Irfan Pathan has said KL Rahul\'s 36-run innings, Virat Kohli\'s half-century, Suryakumar Yadav\'s batting and Ravindra Jadeja\'s bowling were some of the positives from India\'s Asia Cup match against Hong Kong. "Kohli\'s half-century is the biggest positive because of the way he batted...You see the score but we here see how he played...he [was] in control," added Irfan. ',
#   'category': 'sports'},
#  {'title': 'World no. 1 Medvedev moves into US Open 3rd round with straight-sets win',
#   'content': 'Defending champion and world number one Daniil Medvedev entered the third round of the ongoing US Open 2022 after defeating Frenchman Arthur Rinderknech in straight sets. Medvedev won with a scoreline of 6-2, 7-5, 6-3 in two hours and 11 minutes. "In general, I\'m happy with my level in the third set, so that\'s great," said Medvedev after the match.',
#   'category': 'sports'},
#  {'title': "If you get hit by HK, it won't let you sleep: Reetinder on Avesh, Arshdeep",
#   'content': 'Discussing the performance of Team India pacers Avesh Khan and Arshdeep Singh against Hong Kong, ex-India all-rounder Reetinder Singh Sodhi said, "If you get hit by Hong Kong, then it won\'t let you sleep that night." "Arshdeep was missing the radar and Avesh was expensive," added Reetinder. Arshdeep conceded 44 runs against Hong Kong with Avesh giving away 53 runs.',
#   'category': 'sports'},
#  {'title': "Expecting too much too soon will create problems: Karim on Rahul, Virat's batting",
#   'content': 'Referring to KL Rahul and Virat Kohli\'s innings against Hong Kong, former India cricketer Saba Karim has said India could\'ve scored 15-20 more runs in the match but the team needs to "nurture" the experienced players once they come back after a break. "If you expect too much too soon, it will create problems for your own team," added Karim',
#   'category': 'sports'},
#  {'title': "KL Rahul probably has 'more ability' than Rohit Sharma: Gautam Gambhir",
#   'content': 'Discussing Team India opener KL Rahul\'s 36 off 39 balls in the Asia Cup match against Hong Kong, Gautam Gambhir said, "Rahul has so much ability...Only he can stop himself if he doesn\'t play freely." "I won\'t hesitate to say that...he probably has more ability than Rohit Sharma...He\'s shown that by doing it in international cricket," added Gambhir.',
#   'category': 'sports'},
#  {'title': 'This is what I do best: Serena Williams after defeating world no. 2 in US Open ',
#   'content': 'During her on-court interview after defeating world number two Anett Kontaveit in her US Open second-round match, Serena Williams said, "This is what I do best." She added, "I\'m just Serena...I\'m super competitive...I\'m just looking at it as a bonus." The twenty three-time singles\' Grand Slam champion had earlier stated she\'ll be "evolving away" from tennis following the US Open. ',
#   'category': 'sports'},
#  {'title': 'Serena beats world no.2 Anett Kontaveit, enters 3rd round of US Open',
#   'content': 'Discussing her 7-6(4), 2-6, 6-2 win against second seed Anett Kontaveit to enter US Open\'s third round, Serena Williams said, "After losing the second set, I thought \'Oh, my goodness\'." "I had to give my best...because \'this could be it\'," Serena added. "I don\'t have anything to lose. I\'ve had an X on my back since 1999," she stated.',
#   'category': 'sports'},
#  {'title': "Dasun said we have 2 world-class bowlers, I don't see any in SL: B'desh Team Director",
#   'content': 'Bangladesh Team Director Khaled Mahmud has reacted to Sri Lanka captain Dasun Shanaka\'s remark that Bangladesh have "only two world-class bowlers" in their team. Khaled said, "I don\'t see any in Sri Lanka, at least Bangladesh have two. That\'s very good." Dasun made the remark after losing against Afghanistan, claiming that Bangladesh would be an "easier opponent" in Asia Cup.',
#   'category': 'sports'},
#  {'title': 'Hong Kong not the right opposition to judge Virat Kohli: Gambhir',
#   'content': 'Ex-India opener Gautam Gambhir has said Hong Kong are not the right opposition to judge whether Virat Kohli is back in "rhythm". He added, "I hope Kohli will be seen in better rhythm in upcoming matches because it was not that sort of quality bowling." Kohli scored unbeaten 59 runs off 44 balls in the match. ',
#   'category': 'sports'},
#  {'title': "I want Kohli at his best, but just make sure he doesn't score vs Aus: Ponting ",
#   'content': 'Ex-Australia captain Ricky Ponting has said he wants to see Virat Kohli among the leading run scorers in the upcoming T20 World Cup in Australia. "But just make sure he doesn\'t score many runs against Australia," Ponting added jokingly. "The fact that Kohli [took] that month off...to get himself back...There\'re a lot of good signs there," he further said.',
#   'category': 'sports'},
#  {'title': 'HS Prannoy defeats ex-world champion to enter Japan Open quarterfinals',
#   'content': "Shuttler HS Prannoy has entered the quarterfinals of the ongoing Japan Open Super 750 tournament after defeating 2021 men's singles world champion Loh Kean Yew of Singapore. Prannoy won with a scoreline of 22-20, 21-19 in a 44-minute second-round match. The 30-year-old Indian will next face Chinese Taipei's Chou Tien Chen in the last-eight stage.",
#   'category': 'sports'},
#  {'title': "Short of words to describe Suryakumar Yadav's innings: Rohit Sharma",
#   'content': 'India captain Rohit Sharma said "words will be short" to describe Suryakumar Yadav\'s unbeaten 68-run innings against Hong Kong in their Asia Cup match on Wednesday. "We\'ve seen that with Suryakumar every now and then. He comes up with [such] kinds of knocks. He just comes out and bats fearlessly which is what the team expects from him," added Rohit. ',
#   'category': 'sports'},
#  {'title': "Before going to bat, I told Rohit that I'd try to take the tempo up: Suryakumar",
#   'content': 'Talking about his unbeaten 68*(26) against Hong Kong in Asia Cup, Suryakumar Yadav said, "Before [going] out to bat, I spoke to Rohit...and told [him] I\'d try to take the tempo up." Suryakumar came in to bat when India were 94/2 after 12.6 overs and added 98 runs with Virat Kohli. The 31-year-old smashed four sixes in the final over.',
#   'category': 'sports'},
#  {'title': "I wouldn't have agreed to have Pant instead of Hardik in the XI: Gambhir",
#   'content': 'Ex-India opener Gautam Gambhir has said he wouldn\'t have agreed to have Rishabh Pant instead of Hardik Pandya in the playing XI against Hong Kong. "If you\'re resting Hardik, then I think Deepak Hooda, who can bowl a couple of overs, deserves a go," he added. Gambhir, however, also stated that Rishabh should\'ve played, but in place of Dinesh Karthik. ',
#   'category': 'sports'},
#  {'title': 'I was hanging by a thread: Kyrgios on his 2nd round win vs Bonzi in US Open ',
#   'content': 'Australian tennis player Nick Kyrgios has entered the third round of the ongoing US Open 2022 after defeating Frenchman Benjamin Bonzi 7-6(7-3), 6-4, 4-6, 6-4. "I was hanging by a thread. His level today was incredible...I played some really risky tennis late in the fourth, which paid off," said Kyrgios. He\'ll now face American JJ Wolf in the third round.',
#   'category': 'sports'},
#  {'title': '2 top executives at Snap quit hours after report about 20% layoffs emerges',
#   'content': 'Two senior advertising executives at Snap quit hours after a report emerged stating that the company was planning to cut about 20% of its workforce. Earlier, a report by The Verge, while citing sources, said that Snap is planning to lay off 20% of its more than 6,400 employees after it reported weak Q2 results. ',
#   'category': 'technology'},
#  {'title': "Snap CEO confirms 20% job cuts, says 'We must reduce cost to avoid ongoing losses'",
#   'content': 'In a letter to staff posted on Snap’s website, CEO Evan Spiegel has confirmed 20% job cuts at the company as the latest quarterly revenue growth of 8% was "well below" expectations. Spiegel wrote, "Unfortunately, given our current lower rate of revenue growth, it has become clear that we must reduce our cost structure to avoid incurring significant ongoing losses."',
#   'category': 'technology'},
#  {'title': "Musk seeks to delay Twitter trial to Nov amid whistleblower's claims",
#   'content': "Tesla CEO Elon Musk is seeking to delay the trial with Twitter until November, as per court filings. The five-day trial is currently scheduled to start on October 17. The court filings came after Musk's legal team sent a fresh letter to Twitter to include whistleblower Peiter Zatko's claims as another reason to end the $44 billion deal.",
#   'category': 'technology'},
#  {'title': 'Google workers protest outside US offices against $1.2 bn Israeli deal',
#   'content': 'Former and current Google employees protested outside its offices in San Francisco and called for it to end Project Nimbus, a $1.2 billion contract with Israel which includes Amazon as well. An employee said workers went public after their concerns were met with silence internally. Additional demonstrations are planned on September 8 in New York, Bay Area and Seattle.',
#   'category': 'technology'},
#  {'title': "Facebook's Gaming app to be shut down in October this year",
#   'content': "Facebook’s Gaming app for iOS and Android is shutting down and will no longer be available for download from October 28, 2022. The Meta-owned company didn't specify the reason for shutting down the app. While Facebook Gaming was introduced in 2018, it took the service two years to develop a mobile app. \n",
#   'category': 'technology'},
#  {'title': 'Meta takes action against 2.7 cr Facebook, Instagram posts in India',
#   'content': 'Social media giant Meta had taken action against 2.5 crore posts on Facebook and 20 lakh posts on Instagram in July in India under the Information Technology Rules, 2021, it said. Action was taken against 1.73 crore spam content, 27 lakh posts related to "adult nudity and sexual activity" and 23 lakh "violent and graphic content" related content on Facebook.',
#   'category': 'technology'},
#  {'title': 'Japan calls for $24 bn investment to boost battery competitiveness',
#   'content': "Japan's Ministry of Economy, Trade and Industry said that the country needs an investment worth over $24 billion from the public and private sectors to develop a competitive manufacturing base for batteries used in electric vehicles (EVs). A specialist panel has set a target of securing 30,000 trained workers for battery manufacturing and supply chains by 2030.\n",
#   'category': 'technology'},
#  {'title': 'Update Mozilla Firefox browser to avoid various vulnerabilities: CERT-In to users',
#   'content': 'Indian Computer Emergency Response Team (CERT-In) has advised users to immediately update Mozilla Firefox browsers to avoid various vulnerabilities. The bugs in the browser could allow a remote attacker to bypass security restrictions, execute arbitrary code and cause denial of service attack on the targeted system, CERT-In said. Vulnerabilities exist due to abuse of XSLT error handling, it added.',
#   'category': 'technology'},
#  {'title': 'Apple releases iOS 12.5.6 update for older iPhones with security fixes',
#   'content': 'Apple has released an iOS 12.5.6 update for older iPhone, iPod touch and iPad models that are not able to run iOS 13 or newer updates. The update fixes the WebKit vulnerability, which was already fixed in iOS 15.6.1 and iPadOS 15.6.1. It is available for iPhone 5s, iPhone 6, iPhone 6 Plus and iPad Air, among others.',
#   'category': 'technology'},
#  {'title': 'Apple CEO Tim Cook pledges support to Pak amid floods; Malala thanks him',
#   'content': 'Apple CEO Tim Cook has announced support for Pakistan amid the devastating floods. "Apple will donate to relief and recovery efforts on the ground," he said. Activist Malala Yousafzai thanked the Apple CEO for "providing support to Pakistan in this very difficult time". One-third of Pakistan has been completely submerged by historic flooding, which has killed at least 1,191 people.  ',
#   'category': 'technology'},
#  {'title': 'Meta plans to create more paid features for Instagram, Facebook',
#   'content': 'Meta is setting up a new group to create more paid products and features for Facebook, Instagram and WhatsApp. "Any new product will be complementary to our existing ads business," a Meta spokesperson told Reuters on Wednesday. The group, named New Monetization Experiences, will be reportedly led by the company\'s former head of research Pratiti Raychoudhury.',
#   'category': 'technology'},
#  {'title': 'Google to give ₹25 lakh reward for spotting bugs under new programme',
#   'content': 'Google has launched a new Vulnerability Reward Program under which it\'ll award up to $31,337 (nearly ₹25 lakh) to researchers who spot vulnerabilities in Alphabet and Google\'s Open Source projects. The rewards will range from $100 to $31,337. The larger amounts will go to unusual or particularly interesting vulnerabilities, "so creativity is encouraged", Google said while launching the programme.',
#   'category': 'technology'},
#  {'title': "Taiwan looks forward to producing 'democracy chips' with US: Prez",
#   'content': 'Taiwan President Tsai Ing-wen told the governor of the US state of Arizona, Doug Ducey, that the island nation is looking forward to producing "democracy chips" with the US. Taiwan Semiconductor Manufacturing Co Ltd (TSMC) is constructing a $12 billion plant in Arizona. Ducey told Tsai that partnership with Taiwan was "the greatest" in the semiconductor industry.',
#   'category': 'technology'},
#  {'title': "Tech can help solve some of India's biggest challenges: Microsoft Prez",
#   'content': 'Microsoft President Brad Smith on Thursday said technology can help solve some of India\'s biggest challenges like climate change and food security. "I\'m in India as the country celebrates 75 years of Independence. It\'s an exciting time to learn more about...how India\'s innovation is shaping future," Smith said. He\'d earlier said India will become the global superpower in artificial intelligence. ',
#   'category': 'technology'},
#  {'title': 'Malware uses fake Google Translate app to mine crypto on 1.12 lakh PCs: Report',
#   'content': "According to a research by Check Point Research, a malware created by Turkish firm Nitrokod has reportedly been used since 2019 to mine crypto on nearly 1.12 lakh users' personal computers (PCs) without their permission. Hackers wait for a month after the app is installed to start mining crypto to ensure the user doesn't notice changes in PC's power consumption.",
#   'category': 'technology'},
#  {'title': 'Google to award up to $31,337 in new open source bug bounty program',
#   'content': 'Google has launched a new Vulnerability Rewards Program (VRP) to reward researchers for finding bugs in its open source projects. The rewards will range from $100 to $31,337, with larger amounts to be given for finding bugs in most sensitive projects like Angular and Golang. Google said it has given over $38 million through its existing VRP programs so far.',
#   'category': 'technology'},
#  {'title': 'Cybercrime cases in 2021 rose by 5%, fraud most common motive: NCRB',
#   'content': "Cybercrime cases reported in India in 2021 rose by 5% compared with 2020 and fraud was the most common cybercrime motive, according to National Crime Records Bureau's latest data. While charge sheets were filed in only one-third of such cases, the states of Assam, Karnataka, Telangana and UP reported over 70% of cybercrimes. India reported 52,974 cybercrime cases in 2021.",
#   'category': 'technology'},
#  {'title': 'Infosys divests entire stake in US-based Trifacta for $12 million',
#   'content': "Infosys said that it has divested its stake in Trifacta Inc, a data preparation software company, for $12 million. Infosys had invested $4 million in the San Francisco-based company in 2016. It had a minority holding not exceeding 20% of Trifacta's outstanding share capital. Trifacta was founded in 2012 and its investors include Accel, Greylock Partners, Ignition and Cathay Innovation.\n",
#   'category': 'technology'},
#  {'title': 'Tesla tests SUVs under 50°C temperature in Dubai, shares pics',
#   'content': 'Tesla took to Instagram and Twitter to share pictures of its field quality engineers testing SUVs in Dubai. The company said the "extreme heat and durability testing" was conducted during hottest time of the year in Dubai when temperatures reach over 50°C. According to the pictures, Model X Plaid and Model Y were among the vehicles included in the test.',
#   'category': 'technology'},
#  {'title': 'US orders Nvidia, AMD to halt sales of top AI chips to China',
#   'content': "Nvidia and AMD have been ordered by US officials to stop selling some of their high-performance chips to China that can be used for artificial intelligence (AI). This would affect export of Nvidia's A100 and H100 chips and AMD's MI250 chips to China. The restrictions would also cost Nvidia up to $400 million (nearly ₹3,181.5 crore) in potential sales.",
#   'category': 'technology'},
#  {'title': "Microsoft's cloud computing changes criticised by Amazon, Google",
#   'content': "Microsoft's cloud computing changes faced criticisms from Amazon and Google on Tuesday with both saying that the changes discourage customers from switching to rival cloud service providers thereby limiting competition. After cloud service providers complained to the EU antitrust regulators against Microsoft, it announced amended licensing deals and changes that will be brought in on October 1.\n",
#   'category': 'technology'},
#  {'title': 'Netflix hires 2 top advertising executives from Snapchat-parent Snap Inc',
#   'content': "Netflix on Tuesday announced that it has hired two top executives from Snap Inc. The firm's Chief Business Officer Jeremi Gorman has been hired as Netflix's head of worldwide advertising while Snap Inc's VP of advertising sales Peter Naylor has been hired for the same role. The hiring signals Netflix's commitment to building an ad-supported version of its streaming service.",
#   'category': 'technology'},
#  {'title': '45-50 million EVs to be on Indian roads by 2030: KPMG',
#   'content': 'The total number of electric vehicles (EV) on Indian roads is likely to reach 45 to 50 million by 2030, according to a report by consultancy firm KPMG. As per the Ministry of Road Transport and Highways, there are currently 13,92,265 EVs plying on Indian roads and EV sales in India have seen a three-time growth over the past year.',
#   'category': 'technology'},
#  {'title': 'SoftBank Corporate Officer Rajeev Misra steps down amid record loss',
#   'content': "SoftBank Group's Corporate Officer and Executive Vice President Rajeev Misra is stepping down from his roles, the Japanese conglomerate said on Wednesday. This development follows a record loss at the Japanese investment group after a slide in technology stocks. Misra will retain his position as head of SoftBank Investment Advisers, which oversees the first Vision Fund's existing investments.\n",
#   'category': 'technology'},
#  {'title': "Rajeev Sen, Charu Asopa call off their divorce; say 'We've decided to keep our marriage'",
#   'content': 'Rajeev Sen and Charu Asopa, who had earlier confirmed their separation, have decided to call off their divorce. Sharing a picture on Instagram, Charu wrote, "Happy to announce that we have decided to keep our marriage for good." "We both are blessed with a beautiful daughter...Her upbringing & happiness is our number one priority," she added. ',
#   'category': 'entertainment'},
#  {'title': 'Punjabi singer Nirvair Singh dies in road accident in Australia',
#   'content': 'Punjabi singer Nirvair Singh was killed in a crash in Australia on Tuesday, according to 9News. The father-of-two was caught in a three-vehicle collision near Melbourne caused by a speeding Kia sedan, the outlet further said quoting the police. The 23-year-old driver of the sedan has been arrested and charged. Singh, 42, was on his way to a job site.',
#   'category': 'entertainment'},
#  {'title': 'Aamir Khan Productions shares & then deletes apology video on occasion of Jain festival',
#   'content': 'Aamir Khan Productions on Thursday posted and later deleted a video on the occasion of the Jain festival of Samvatsari. The video, which started with the phrase \'Micchami Dukkadam\', carried a Hindi voiceover that said, “Hum sab insane hai…Aur galtiyan humse...hoti hai." It further said that if I\'ve ever hurt your feelings, then I ask for forgiveness.',
#   'category': 'entertainment'},
#  {'title': 'Jacqueline deleted data on Sukesh from her phones to hamper investigation: ED',
#   'content': 'The Enforcement Directorate in its chargesheet has said that actress Jacqueline Fernandez "knowingly and deliberately deleted all the data" with respect to conman Sukesh Chandrashekhar from her phones with an aim to "hamper the investigation" to save herself and her family. She allegedly also requested her staff to delete data related to Sukesh from their phones. ',
#   'category': 'entertainment'},
#  {'title': "Don't eff this up: Bezos recalls warning from son for Lord of Rings' prequel",
#   'content': 'Ahead of the debut of The Lord of the Rings\' prequel \'Rings of Power\' on Amazon\'s Prime Video, Jeff Bezos revealed a conversation he had with his son. He said, "My son came up to me one day, he looked me in the eyes, very sincerely, and he said: \'Dad, please don\'t eff this up\'...And he was right."',
#   'category': 'entertainment'},
#  {'title': "I dream of buying a private jet, don't have to prove I'm relatable: Kartik",
#   'content': 'Actor Kartik Aaryan has revealed that his dreams are getting bigger and said that his wishes of buying a Lamborghini and becoming an actor were fulfilled. Kartik was asked if he now dreams of buying a private jet. To this, he replied, "Private jet should also come...I don\'t have to prove that I come from Gwalior and that I\'m relatable."',
#   'category': 'entertainment'},
#  {'title': "Films with bad scripts get rejected, I'm one of the victims: Chiranjeevi",
#   'content': 'Actor Chiranjeevi said the number of people coming to theatres has gone down after the pandemic. However, he added people will come if the film\'s script is good. "The bad films get rejected on the second day of their release. I\'m one of the victims of this trend," he added. Chiranjeevi\'s \'Acharya\' failed to perform at the box office.',
#   'category': 'entertainment'},
#  {'title': 'Riteish, Genelia buy BMW iX electric car worth around ₹1.43 crore',
#   'content': "Actor Riteish Deshmukh and his wife Genelia Deshmukh bought BMW iX electric car on Ganesh Chaturthi. The two, along with their kids Riaan and Rahyl, were seen arriving at Arpita Khan Sharma and Aayush Sharma's house in their new car, which costs around ₹1.43 crore. The new model is the first-ever all-electric variant of the iX. ",
#   'category': 'entertainment'},
#  {'title': 'Been single for 1.25 yrs: Kartik on if he lied about his relationship with Sara',
#   'content': 'Actor Kartik Aaryan, during an interview, was asked if he lied about his relationship with Sara Ali Khan after Karan Johar confirmed his relationship on \'Koffee With Karan\'. To this, he replied, "I\'ve been single [for] the past 1.25 years, I don\'t know about anything else." Kartik and Sara were rumoured to be dating while filming \'Love Aaj Kal 2\'.',
#   'category': 'entertainment'},
#  {'title': "Tiger says Rekha played Big B's mother & love interest in films, Karan reacts",
#   'content': 'During the quiz round in the \'Koffee With Karan 7\' episode featuring Kriti Sanon and Tiger Shroff, Karan Johar asked them to name the actress who played both Amitabh Bachchan\'s mother and love interest in films. Tiger replied, "Rekha ma\'am?" Reacting to this, Karan said, "What? She never...played his mother." Karan revealed the actresses were Waheeda Rehman and Rakhee.',
#   'category': 'entertainment'},
#  {'title': 'PM Modi is strong personality yet sensitive at heart: Film producer Jain',
#   'content': 'Film producer Mahaveer Jain said that he was "very fortunate" to meet Prime Minister Narendra Modi. Speaking about PM Modi, Mahaveer said, "He is a very strong personality yet very sensitive and emotional at heart." Jain further added, "He himself is a very creative person who admires the creative fraternity for its positive contribution."',
#   'category': 'entertainment'},
#  {'title': "I wouldn't date Kartik Aaryan as I know him 'too well': Kriti Sanon",
#   'content': 'Actress Kriti Sanon said one of the reasons why she wouldn\'t date actor Kartik Aaryan is because she knows him "too well". Kriti added that a reason why she\'d date Kartik is because she knows him well. Talking about actor Tiger Shroff, Kriti stated that one of the reasons she wouldn\'t date the actor is because he "flips too much".',
#   'category': 'entertainment'},
#  {'title': "Alia Bhatt's work drives me, inspires me to do better: Kriti Sanon",
#   'content': 'Responding to a question by Karan Johar over her thoughts on actress Alia Bhatt being the best actress currently, actress Kriti Sanon said, "[Alia\'s work] drives me." "It inspires me to do better when I see great work. I would love to have an opportunity like \'Gangubai Kathiawadi\'," she added. Recently, Kriti won Best Actress at Filmfare Awards for \'Mimi\'.  ',
#   'category': 'entertainment'},
#  {'title': 'Learned how to face camera from Kareena: Kiara',
#   'content': 'Kiara Advani said she "learned how to face the camera" from her \'Good Newwz\' co-star Kareena Kapoor Khan. She said during the film\'s shoot, she used to be so involved in a scene that she would forget about camera angles. However, that never happened with Kareena. Kiara said Kareena "would know where the camera is, even if it\'s behind her".',
#   'category': 'entertainment'},
#  {'title': "S Korea may hold survey on BTS members' mandatory military service",
#   'content': "South Korea is considering a survey to determine whether members of K-pop band BTS should be granted exemptions from mandatory military service, officials said. The Defence Ministry is examining the adequacy of such a study. The military service issue has been debated in the media recently as BTS's oldest member, Jin, faces enlistment at year-end, when he turns 30.",
#   'category': 'entertainment'},
#  {'title': "I was depressed & heartbroken: Tiger Shroff on recent 'setback' in films",
#   'content': 'Talking about his reaction after his recent film didn\'t perform well, during his appearance on \'Koffee With Karan 7\', actor Tiger Shroff said, "I was heartbroken. I was depressed." "I\'m just a very extreme person, I wouldn\'t say I sacrificed a lot because I like what I do," he further added. The actor\'s recent film \'Heropanti 2\' failed to perform.',
#   'category': 'entertainment'},
#  {'title': 'Tried to do matchmaking at party, asked Shanaya to speak to Tiger: Johar',
#   'content': 'Filmmaker Karan Johar said he tried to engage in "matchmaking" during one of his parties by asking actor Sanjay Kapoor\'s daughter Shanaya Kapoor to speak to actor Tiger Shroff. "After ten minutes, Shanaya came...and said, \'I think he\'s really bored of me\'," added Johar. Tiger responded by stating that he\'s feeling very \'\'bad", adding he thought he was being cool.',
#   'category': 'entertainment'},
#  {'title': "At this stage of my life, I don't have to work for stardom or money: Nagarjuna",
#   'content': 'Actor Nagarjuna has said that he wants to keep working till he can. "At this stage of my life, I don\'t have to work for stardom or money...except job satisfaction," he stated. Nagarjuna added, "My father literally died with his boots on. He collapsed on the set of a film. For an actor what can be better than that?"',
#   'category': 'entertainment'},
#  {'title': '1st feedback of Dil Se was bad, exhibitors felt killing SRK was mistake: RGV',
#   'content': 'Filmmaker Ram Gopal Varma has revealed the immediate feedback of the 1998 film \'Dil Se..\' was negative. "The exhibitors felt that killing Shah Rukh Khan was a mistake. They told us that due to the tragic ending, the viewers are giving the film thumbs down," he added. Varma, who was one of the film\'s producers, stated they were all panicking.  ',
#   'category': 'entertainment'},
#  {'title': "Working with Ranbir, Big B in 'Brahmastra' was dream come true: Soni",
#   'content': 'Actor Markand Soni said working with actors Ranbir Kapoor and Amitabh Bachchan was a "100%" dream come true. "I\'ve never met someone as kind and as sweet as Ranbir Kapoor and Amitabh Bachchan sir," he added. Soni further called them grounded. \'\'\'Brahmastra\' is going to be like something you have never seen before in the Hindi film industry," he added.',
#   'category': 'entertainment'},
#  {'title': "Amitabh Bachchan tests negative for COVID-19, resumes 'KBC 14' shoot",
#   'content': 'Amitabh Bachchan said he has tested negative for COVID-19 and is "back at work". He also expressed his gratitude to his fans for their prayers and concern. A source informed Indian Express that Amitabh has resumed \'Kaun Banega Crorepati 14\' shoot, and this time, the reality show\'s producers have made COVID-19 safety protocols "a little stricter" on sets. ',
#   'category': 'entertainment'},
#  {'title': "'The Kapil...' is my show as well, I'll be back again: Krushna Abhishek",
#   'content': 'Actor-comedian Krushna Abhishek has said that \'The Kapil Sharma Show\' is his show as well and revealed that he will be back again. Speaking about the rumours about the tension between him and Kapil Sharma, Krushna said, "There is no issue." This comes as Krushna had previously said he will not be featuring in the show due to "agreement issues".',
#   'category': 'entertainment'},
#  {'title': "Wanted my debut to be role which makes difference: Sargun on 'Cuttputlli'",
#   'content': 'Actress Sargun Mehta, who will be making her Bollywood debut with \'Cuttputlli\', said, "I always wanted my debut to be a role which makes a difference to the story irrespective of the length." She added the subject of the film was "very interesting". Sargun stated, "I was getting an opportunity to work with Akshay Kumar, who is a brilliant actor."',
#   'category': 'entertainment'},
#  {'title': "Salman Khan's 'Bigg Boss 16' to premiere in October: Reports",
#   'content': "'Bigg Boss 16' makers have reportedly locked the premiere date of its upcoming season. The makers of the Salman Khan-hosted reality show are reportedly planning to lock either October 8 or October 9 for Bigg Boss 16's premiere. Earlier, the new season was supposed to launch on October 1, but the makers decided to push it for a week. ",
#   'category': 'entertainment'},
#  {'title': 'Would like to work with Vijay in Ajay Gnanamuthu directorial: Vikram',
#   'content': "Tamil actor Chiyaan Vikram has shared that he would like to work with his contemporary Vijay under the direction of filmmaker Ajay Gnanamuthu. Vikram spoke about Vijay during a Twitter conversation, which was conducted on Tuesday to promote his film 'Cobra'. In response, director Ajay Gnanamuthu said he would be the first person to buy a ticket for the film. ",
#   'category': 'entertainment'}]

# %%
news_df= pd.DataFrame(news_df)
news_df.head()
# Out:
#                                                title  \
# 0  Don't eff this up: Bezos recalls warning from ...
# 1  Snap CEO confirms 20% job cuts, says 'We must ...
# 2  Price of commercial LPG cylinders cut by up to...
# 3  Chairman of Russia's 2nd largest oil firm dies...
# 4  SpiceJet shares fall nearly 15% after CFO resi...
#
#                                              content  category
# 0  Ahead of the debut of The Lord of the Rings' p...  business
# 1  In a letter to staff posted on Snap’s website,...  business
# 2  State-owned fuel retailers on Thursday announc...  business
# 3  The chairman of Russia's second-largest oil pr...  business
# 4  SpiceJet shares declined nearly 15% during Thu...  business

# %%
news_df= prepare.prepare_data(news_df,'content')

# %%
news_df.head()
# Out:
#                                                title  \
# 0  Don't eff this up: Bezos recalls warning from ...
# 1  Snap CEO confirms 20% job cuts, says 'We must ...
# 2  Price of commercial LPG cylinders cut by up to...
# 3  Chairman of Russia's 2nd largest oil firm dies...
# 4  SpiceJet shares fall nearly 15% after CFO resi...
#
#                                              content  category  \
# 0  Ahead of the debut of The Lord of the Rings' p...  business
# 1  In a letter to staff posted on Snap’s website,...  business
# 2  State-owned fuel retailers on Thursday announc...  business
# 3  The chairman of Russia's second-largest oil pr...  business
# 4  SpiceJet shares declined nearly 15% during Thu...  business
#
#                                                clean  \
# 0  ahead debut lord rings prequel rings power ama...
# 1  letter staff posted snaps website ceo evan spi...
# 2  stateowned fuel retailers thursday announced r...
# 3  chairman russias secondlargest oil producer lu...
# 4  spicejet shares declined nearly 15 thursdays i...
#
#                                              stemmed  \
# 0  ahead debut lord ring prequel ring power amazo...
# 1  letter staff post snap websit ceo evan spiegel...
# 2  stateown fuel retail thursday announc reduct p...
# 3  chairman russia secondlargest oil produc lukoi...
# 4  spicejet share declin nearli 15 thursday intra...
#
#                                           lemmatized
# 0  ahead debut lord ring prequel ring power amazo...
# 1  letter staff posted snap website ceo evan spie...
# 2  stateowned fuel retailer thursday announced re...
# 3  chairman russia secondlargest oil producer luk...
# 4  spicejet share declined nearly 15 thursday int...

# %%
# lets remove unnecessary characters from the lemmatized and then split it to get the list of the list of words

words = [re.sub(r'([^a-z0-9\s]|\s.\s)','',doc).split() for doc in news_df.lemmatized]

# %%
news_df = pd.concat([news_df, pd.DataFrame({'words':words})], axis = 1)

# %%
news_df
# Out:
#                                                 title  \
# 0   Don't eff this up: Bezos recalls warning from ...
# 1   Snap CEO confirms 20% job cuts, says 'We must ...
# 2   Price of commercial LPG cylinders cut by up to...
# 3   Chairman of Russia's 2nd largest oil firm dies...
# 4   SpiceJet shares fall nearly 15% after CFO resi...
# ..                                                ...
# 92  Amitabh Bachchan tests negative for COVID-19, ...
# 93  'The Kapil...' is my show as well, I'll be bac...
# 94  Wanted my debut to be role which makes differe...
# 95  Salman Khan's 'Bigg Boss 16' to premiere in Oc...
# 96  Would like to work with Vijay in Ajay Gnanamut...
#
#                                               content       category  \
# 0   Ahead of the debut of The Lord of the Rings' p...       business
# 1   In a letter to staff posted on Snap’s website,...       business
# 2   State-owned fuel retailers on Thursday announc...       business
# 3   The chairman of Russia's second-largest oil pr...       business
# 4   SpiceJet shares declined nearly 15% during Thu...       business
# ..                                                ...            ...
# 92  Amitabh Bachchan said he has tested negative f...  entertainment
# 93  Actor-comedian Krushna Abhishek has said that ...  entertainment
# 94  Actress Sargun Mehta, who will be making her B...  entertainment
# 95  'Bigg Boss 16' makers have reportedly locked t...  entertainment
# 96  Tamil actor Chiyaan Vikram has shared that he ...  entertainment
#
#                                                 clean  \
# 0   ahead debut lord rings prequel rings power ama...
# 1   letter staff posted snaps website ceo evan spi...
# 2   stateowned fuel retailers thursday announced r...
# 3   chairman russias secondlargest oil producer lu...
# 4   spicejet shares declined nearly 15 thursdays i...
# ..                                                ...
# 92  amitabh bachchan said tested negative covid19 ...
# 93  actorcomedian krushna abhishek said kapil shar...
# 94  actress sargun mehta making bollywood debut cu...
# 95  bigg boss 16 makers reportedly locked premiere...
# 96  tamil actor chiyaan vikram shared would like w...
#
#                                               stemmed  \
# 0   ahead debut lord ring prequel ring power amazo...
# 1   letter staff post snap websit ceo evan spiegel...
# 2   stateown fuel retail thursday announc reduct p...
# 3   chairman russia secondlargest oil produc lukoi...
# 4   spicejet share declin nearli 15 thursday intra...
# ..                                                ...
# 92  amitabh bachchan said test neg covid19 back wo...
# 93  actorcomedian krushna abhishek said kapil shar...
# 94  actress sargun mehta make bollywood debut cutt...
# 95  bigg boss 16 maker reportedli lock premier dat...
# 96  tamil actor chiyaan vikram share would like wo...
#
#                                            lemmatized  \
# 0   ahead debut lord ring prequel ring power amazo...
# 1   letter staff posted snap website ceo evan spie...
# 2   stateowned fuel retailer thursday announced re...
# 3   chairman russia secondlargest oil producer luk...
# 4   spicejet share declined nearly 15 thursday int...
# ..                                                ...
# 92  amitabh bachchan said tested negative covid19 ...
# 93  actorcomedian krushna abhishek said kapil shar...
# 94  actress sargun mehta making bollywood debut cu...
# 95  bigg bos 16 maker reportedly locked premiere d...
# 96  tamil actor chiyaan vikram shared would like w...
#
#                                                 words
# 0   [ahead, debut, lord, ring, prequel, ring, powe...
# 1   [letter, staff, posted, snap, website, ceo, ev...
# 2   [stateowned, fuel, retailer, thursday, announc...
# 3   [chairman, russia, secondlargest, oil, produce...
# 4   [spicejet, share, declined, nearly, 15, thursd...
# ..                                                ...
# 92  [amitabh, bachchan, said, tested, negative, co...
# 93  [actorcomedian, krushna, abhishek, said, kapil...
# 94  [actress, sargun, mehta, making, bollywood, de...
# 95  [bigg, bos, 16, maker, reportedly, locked, pre...
# 96  [tamil, actor, chiyaan, vikram, shared, would,...
#
# [97 rows x 7 columns]

# %%
# lets join all of the words by category together

business_words = ' '.join(news_df[news_df.title == 'business'].lemmatized)
sports_words = ' '.join(news_df[news_df.title == 'sports'].lemmatized)
technology_words = ' '.join(news_df[news_df.title == 'technology'].lemmatized)
entertainment_words = ' '.join(news_df[news_df.title == 'entertainment'].lemmatized)
all_words = ' '.join(news_df.lemmatized)

# %%
# lets split all of the words in each category and convert it to pandas series and get a value count

business_freq = pd.Series(business_words.split()).value_counts()
sports_freq = pd.Series(sports_words.split()).value_counts()
technology_freq = pd.Series(technology_words.split()).value_counts()
entertainment_freq = pd.Series(entertainment_words.split()).value_counts()
all_freq = pd.Series(all_words.split()).value_counts()
# Out:
# /var/folders/h9/174nr99d0zl_7cgtzqpv_gzw144wkq/T/ipykernel_73003/3752690884.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   business_freq = pd.Series(business_words.split()).value_counts()
# /var/folders/h9/174nr99d0zl_7cgtzqpv_gzw144wkq/T/ipykernel_73003/3752690884.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   sports_freq = pd.Series(sports_words.split()).value_counts()
# /var/folders/h9/174nr99d0zl_7cgtzqpv_gzw144wkq/T/ipykernel_73003/3752690884.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   technology_freq = pd.Series(technology_words.split()).value_counts()
# /var/folders/h9/174nr99d0zl_7cgtzqpv_gzw144wkq/T/ipykernel_73003/3752690884.py:6: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   entertainment_freq = pd.Series(entertainment_words.split()).value_counts()

# %%
# lets create a dataframe that holds the word counts for each category 

words_count = (pd.concat([all_freq, business_freq, sports_freq, technology_freq, entertainment_freq], axis = 1,sort = True)\
.set_axis(['all', 'business', 'sports', 'technology', 'entertainment'], axis = 1)\
.fillna(0)
.apply(lambda s:s.astype(int))
)

# %%
words_count.head()
# Out:
#       all  business  sports  technology  entertainment
# 05      1         0       0           0              0
# 1       3         0       0           0              0
# 10      2         0       0           0              0
# 100     4         0       0           0              0
# 1052    1         0       0           0              0

# %%
words_count.sort_values('all').head(10)
# Out:
#                all  business  sports  technology  entertainment
# 05               1         0       0           0              0
# meet             1         0       0           0              0
# mechthild        1         0       0           0              0
# measure          1         0       0           0              0
# mathrubootham    1         0       0           0              0
# matchmaking      1         0       0           0              0
# marriage         1         0       0           0              0
# markand          1         0       0           0              0
# mehta            1         0       0           0              0
# mangalore        1         0       0           0              0
